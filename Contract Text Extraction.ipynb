# %% [markdown]
# # LEGAL CONTRACT CLASSIFICATION:

# %% [markdown]
# ## STEP 1: Perform Text Extraction for Contract PDF

# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\rohaan\anaconda3\lib\site-packages (1.26.0)

# %%
import PyPDF2 as pdf

# %% [markdown]
# Below contract being extracted is an Assignment Order Contract

# %%
file = open('Contract-AO.pdf', 'rb')

# %%
file
# Out:
# <_io.BufferedReader name='Contract-AO.pdf'>

# %%
pdf_reader = pdf.PdfFileReader(file)

# %%
pdf_reader

# %%
pdf_reader.getIsEncrypted()
# Out:
# False

# %%
pdf_reader.getNumPages()
# Out:
# 1

# %%
page1 = pdf_reader.getPage(0)

# %%
page1.extractText()
# Out:
# 'FAS\n-\nXXX\n-\n001\n \n \nCONFIDENTIAL\n \n \nPage \n1\n \nof \n1\n \n<Date>\n \n \nAssignment Order\n \n \n\nAssignment Order\n\n\nAO\n\nunder the terms and conditions of the \nProfessional Services Agreement \n\nbetween \n<\nCompany \nName>\n \n\nand \nForgeahead Solutions\n, Inc.\n \n\n<da\nte>\n. \nUnder this \nAO\n, \nConsultant\n \nwill \nprovide services as defined below in Work Activities.  The expected period of performance will be \nfrom \n<Start Date>\n \nthrough \n<End Date>\n.\n \nThis Assignment Order forms and shall always be deemed to have formed an integral pa\nrt of the \nAgreement. In the event of any conflict or inconsistency between the provisions of the Agreement \nand this Assignment Order, the provisions of this Assignment Order will prevail.\n \n \nProject Name\n \n<Project Name if any>\n \n \nAO\n# \n \nFor billing and accounting\n \npurposes, this \nAO\n \nwill be referred to as \nFAS\n-\nXXX\n-\n001\n \n \nWork Activities\n \nThe work activity in which \nCompany \nexpects \nConsultant \nto be engaged is categorized as follows:\n \n<Nature of \nServices\n>\n \ncomprising a \nTeam \nof\n:\n \n1.\n \n<Team Size>\n \n \nWork Hours\n \nEach month will consis\nt of the actual number of working days in that month and each week to \nconsist of a maximum of 5 working days (Monday through Friday) with a maximum of 45 hours. \nCompany \nshall\n \ngrant \nConsultant\n\nf\n \nas company declared holidays and \n21\n \ndays\n \nas personal vacation during each calendar year for which there would be no deduction in \npayments / invoice. All overtime will be separately identified and charge\nd on pro\n-\nrata basis. \n \n \nProfessional Services Billing Rate\n \nConsultant will accrue earnings at t\nhe rate of \n \n\n \n<Rate In Figure>\n \n(US Dollar/Rupees \n<In Words>\n \nonly) \n \n \nRequired Training, Work Equipment and Software\n \nThe work defined in this \nAO\n \nwill require certain training, equipment and software.  It is the \nresponsibility of \nCompany \nto provide all training\n, hardware and software for use by \nConsultant \nin \nthe completion of this Assignment Order.\n \n \nTravel\n \nConsultant \nmay be \nexpected to travel to complete the Work Activities listed in this Assignment \nOrder.\n \nCompany \nagrees to pay for all expenses met by \nConsultant\n\nfor such travel \nincluding but not limited to Airfare, Lodging, meals etc.\n \n \nAgreed and Accepted by:\n \n \nForgeahead Solutions\n, Inc.\n \n \n \n \n \n<\nCompany\n \nName>\n \n \n \n \n<Name>\n \n \n \n \n \n \n \n<Name>\n \n<Title>\n \n \n \n \n \n \n \n \n<Title>\n \n'

# %% [markdown]
# ## STEP 2: Convert Extracted Text to Lowercase String for Preprocessing

# %%
Page1 = str(page1.extractText())
Page1 = Page1.lower()

# %%
Page1
# Out:
# 'fas\n-\nxxx\n-\n001\n \n \nconfidential\n \n \npage \n1\n \nof \n1\n \n<date>\n \n \nassignment order\n \n \n\nassignment order\n\n\nao\n\nunder the terms and conditions of the \nprofessional services agreement \n\nbetween \n<\ncompany \nname>\n \n\nand \nforgeahead solutions\n, inc.\n \n\n<da\nte>\n. \nunder this \nao\n, \nconsultant\n \nwill \nprovide services as defined below in work activities.  the expected period of performance will be \nfrom \n<start date>\n \nthrough \n<end date>\n.\n \nthis assignment order forms and shall always be deemed to have formed an integral pa\nrt of the \nagreement. in the event of any conflict or inconsistency between the provisions of the agreement \nand this assignment order, the provisions of this assignment order will prevail.\n \n \nproject name\n \n<project name if any>\n \n \nao\n# \n \nfor billing and accounting\n \npurposes, this \nao\n \nwill be referred to as \nfas\n-\nxxx\n-\n001\n \n \nwork activities\n \nthe work activity in which \ncompany \nexpects \nconsultant \nto be engaged is categorized as follows:\n \n<nature of \nservices\n>\n \ncomprising a \nteam \nof\n:\n \n1.\n \n<team size>\n \n \nwork hours\n \neach month will consis\nt of the actual number of working days in that month and each week to \nconsist of a maximum of 5 working days (monday through friday) with a maximum of 45 hours. \ncompany \nshall\n \ngrant \nconsultant\n\nf\n \nas company declared holidays and \n21\n \ndays\n \nas personal vacation during each calendar year for which there would be no deduction in \npayments / invoice. all overtime will be separately identified and charge\nd on pro\n-\nrata basis. \n \n \nprofessional services billing rate\n \nconsultant will accrue earnings at t\nhe rate of \n \n\n \n<rate in figure>\n \n(us dollar/rupees \n<in words>\n \nonly) \n \n \nrequired training, work equipment and software\n \nthe work defined in this \nao\n \nwill require certain training, equipment and software.  it is the \nresponsibility of \ncompany \nto provide all training\n, hardware and software for use by \nconsultant \nin \nthe completion of this assignment order.\n \n \ntravel\n \nconsultant \nmay be \nexpected to travel to complete the work activities listed in this assignment \norder.\n \ncompany \nagrees to pay for all expenses met by \nconsultant\n\nfor such travel \nincluding but not limited to airfare, lodging, meals etc.\n \n \nagreed and accepted by:\n \n \nforgeahead solutions\n, inc.\n \n \n \n \n \n<\ncompany\n \nname>\n \n \n \n \n<name>\n \n \n \n \n \n \n \n<name>\n \n<title>\n \n \n \n \n \n \n \n \n<title>\n \n'

# %% [markdown]
# ## STEP 3: Convert String to List Data Type so that we can iterate over the corpus

# %%
list1 = Page1.split()

# %%
list1
# Out:
# ['fas',
#  '-',
#  'xxx',
#  '-',
#  '001',
#  'confidential',
#  'page',
#  '1',
#  'of',
#  '1',
#  '<date>',
#  'assignment',
#  'order',
#  'assignment',
#  'order',
#  'ao',
#  'under',
#  'the',
#  'terms',
#  'and',
#  'conditions',
#  'of',
#  'the',
#  'professional',
#  'services',
#  'agreement',
#  'between',
#  '<',
#  'company',
#  'name>',
#  'and',
#  'forgeahead',
#  'solutions',
#  ',',
#  'inc.',
#  '<da',
#  'te>',
#  '.',
#  'under',
#  'this',
#  'ao',
#  ',',
#  'consultant',
#  'will',
#  'provide',
#  'services',
#  'as',
#  'defined',
#  'below',
#  'in',
#  'work',
#  'activities.',
#  'the',
#  'expected',
#  'period',
#  'of',
#  'performance',
#  'will',
#  'be',
#  'from',
#  '<start',
#  'date>',
#  'through',
#  '<end',
#  'date>',
#  '.',
#  'this',
#  'assignment',
#  'order',
#  'forms',
#  'and',
#  'shall',
#  'always',
#  'be',
#  'deemed',
#  'to',
#  'have',
#  'formed',
#  'an',
#  'integral',
#  'pa',
#  'rt',
#  'of',
#  'the',
#  'agreement.',
#  'in',
#  'the',
#  'event',
#  'of',
#  'any',
#  'conflict',
#  'or',
#  'inconsistency',
#  'between',
#  'the',
#  'provisions',
#  'of',
#  'the',
#  'agreement',
#  'and',
#  'this',
#  'assignment',
#  'order,',
#  'the',
#  'provisions',
#  'of',
#  'this',
#  'assignment',
#  'order',
#  'will',
#  'prevail.',
#  'project',
#  'name',
#  '<project',
#  'name',
#  'if',
#  'any>',
#  'ao',
#  '#',
#  'for',
#  'billing',
#  'and',
#  'accounting',
#  'purposes,',
#  'this',
#  'ao',
#  'will',
#  'be',
#  'referred',
#  'to',
#  'as',
#  'fas',
#  '-',
#  'xxx',
#  '-',
#  '001',
#  'work',
#  'activities',
#  'the',
#  'work',
#  'activity',
#  'in',
#  'which',
#  'company',
#  'expects',
#  'consultant',
#  'to',
#  'be',
#  'engaged',
#  'is',
#  'categorized',
#  'as',
#  'follows:',
#  '<nature',
#  'of',
#  'services',
#  '>',
#  'comprising',
#  'a',
#  'team',
#  'of',
#  ':',
#  '1.',
#  '<team',
#  'size>',
#  'work',
#  'hours',
#  'each',
#  'month',
#  'will',
#  'consis',
#  't',
#  'of',
#  'the',
#  'actual',
#  'number',
#  'of',
#  'working',
#  'days',
#  'in',
#  'that',
#  'month',
#  'and',
#  'each',
#  'week',
#  'to',
#  'consist',
#  'of',
#  'a',
#  'maximum',
#  'of',
#  '5',
#  'working',
#  'days',
#  '(monday',
#  'through',
#  'friday)',
#  'with',
#  'a',
#  'maximum',
#  'of',
#  '45',
#  'hours.',
#  'company',
#  'shall',
#  'grant',
#  'consultant',
#  'f',
#  'as',
#  'company',
#  'declared',
#  'holidays',
#  'and',
#  '21',
#  'days',
#  'as',
#  'personal',
#  'vacation',
#  'during',
#  'each',
#  'calendar',
#  'year',
#  'for',
#  'which',
#  'there',
#  'would',
#  'be',
#  'no',
#  'deduction',
#  'in',
#  'payments',
#  '/',
#  'invoice.',
#  'all',
#  'overtime',
#  'will',
#  'be',
#  'separately',
#  'identified',
#  'and',
#  'charge',
#  'd',
#  'on',
#  'pro',
#  '-',
#  'rata',
#  'basis.',
#  'professional',
#  'services',
#  'billing',
#  'rate',
#  'consultant',
#  'will',
#  'accrue',
#  'earnings',
#  'at',
#  't',
#  'he',
#  'rate',
#  'of',
#  '<rate',
#  'in',
#  'figure>',
#  '(us',
#  'dollar/rupees',
#  '<in',
#  'words>',
#  'only)',
#  'required',
#  'training,',
#  'work',
#  'equipment',
#  'and',
#  'software',
#  'the',
#  'work',
#  'defined',
#  'in',
#  'this',
#  'ao',
#  'will',
#  'require',
#  'certain',
#  'training,',
#  'equipment',
#  'and',
#  'software.',
#  'it',
#  'is',
#  'the',
#  'responsibility',
#  'of',
#  'company',
#  'to',
#  'provide',
#  'all',
#  'training',
#  ',',
#  'hardware',
#  'and',
#  'software',
#  'for',
#  'use',
#  'by',
#  'consultant',
#  'in',
#  'the',
#  'completion',
#  'of',
#  'this',
#  'assignment',
#  'order.',
#  'travel',
#  'consultant',
#  'may',
#  'be',
#  'expected',
#  'to',
#  'travel',
#  'to',
#  'complete',
#  'the',
#  'work',
#  'activities',
#  'listed',
#  'in',
#  'this',
#  'assignment',
#  'order.',
#  'company',
#  'agrees',
#  'to',
#  'pay',
#  'for',
#  'all',
#  'expenses',
#  'met',
#  'by',
#  'consultant',
#  'for',
#  'such',
#  'travel',
#  'including',
#  'but',
#  'not',
#  'limited',
#  'to',
#  'airfare,',
#  'lodging,',
#  'meals',
#  'etc.',
#  'agreed',
#  'and',
#  'accepted',
#  'by:',
#  'forgeahead',
#  'solutions',
#  ',',
#  'inc.',
#  '<',
#  'company',
#  'name>',
#  '<name>',
#  '<name>',
#  '<title>',
#  '<title>']

# %% [markdown]
# ## STEP 4: Perform Stemming/ Lemmitization to Convert Strings in List to Root Form

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer(language='english')
stemmed_list = [stemmer.stem(token) for token in list1]
print(' '.join(stemmed_list))
# Out:
# fas - xxx - 001 confidenti page 1 of 1 <date> assign order assign order ao under the term and condit of the profession servic agreement between < compani name> and forgeahead solut , inc. <da te> . under this ao , consult will provid servic as defin below in work activities. the expect period of perform will be from <start date> through <end date> . this assign order form and shall alway be deem to have form an integr pa rt of the agreement. in the event of ani conflict or inconsist between the provis of the agreement and this assign order, the provis of this assign order will prevail. project name <project name if any> ao # for bill and account purposes, this ao will be refer to as fas - xxx - 001 work activ the work activ in which compani expect consult to be engag is categor as follows: <natur of servic > compris a team of : 1. <team size> work hour each month will consi t of the actual number of work day in that month and each week to consist of a maximum of 5 work day (monday through friday) with a maximum of 45 hours. compani shall grant consult f as compani declar holiday and 21 day as person vacat dure each calendar year for which there would be no deduct in payment / invoice. all overtim will be separ identifi and charg d on pro - rata basis. profession servic bill rate consult will accru earn at t he rate of <rate in figure> (us dollar/rupe <in words> only) requir training, work equip and softwar the work defin in this ao will requir certain training, equip and software. it is the respons of compani to provid all train , hardwar and softwar for use by consult in the complet of this assign order. travel consult may be expect to travel to complet the work activ list in this assign order. compani agre to pay for all expens met by consult for such travel includ but not limit to airfare, lodging, meal etc. agre and accept by: forgeahead solut , inc. < compani name> <name> <name> <title> <title>

# %%
stemmed_list
# Out:
# ['fas',
#  '-',
#  'xxx',
#  '-',
#  '001',
#  'confidenti',
#  'page',
#  '1',
#  'of',
#  '1',
#  '<date>',
#  'assign',
#  'order',
#  'assign',
#  'order',
#  'ao',
#  'under',
#  'the',
#  'term',
#  'and',
#  'condit',
#  'of',
#  'the',
#  'profession',
#  'servic',
#  'agreement',
#  'between',
#  '<',
#  'compani',
#  'name>',
#  'and',
#  'forgeahead',
#  'solut',
#  ',',
#  'inc.',
#  '<da',
#  'te>',
#  '.',
#  'under',
#  'this',
#  'ao',
#  ',',
#  'consult',
#  'will',
#  'provid',
#  'servic',
#  'as',
#  'defin',
#  'below',
#  'in',
#  'work',
#  'activities.',
#  'the',
#  'expect',
#  'period',
#  'of',
#  'perform',
#  'will',
#  'be',
#  'from',
#  '<start',
#  'date>',
#  'through',
#  '<end',
#  'date>',
#  '.',
#  'this',
#  'assign',
#  'order',
#  'form',
#  'and',
#  'shall',
#  'alway',
#  'be',
#  'deem',
#  'to',
#  'have',
#  'form',
#  'an',
#  'integr',
#  'pa',
#  'rt',
#  'of',
#  'the',
#  'agreement.',
#  'in',
#  'the',
#  'event',
#  'of',
#  'ani',
#  'conflict',
#  'or',
#  'inconsist',
#  'between',
#  'the',
#  'provis',
#  'of',
#  'the',
#  'agreement',
#  'and',
#  'this',
#  'assign',
#  'order,',
#  'the',
#  'provis',
#  'of',
#  'this',
#  'assign',
#  'order',
#  'will',
#  'prevail.',
#  'project',
#  'name',
#  '<project',
#  'name',
#  'if',
#  'any>',
#  'ao',
#  '#',
#  'for',
#  'bill',
#  'and',
#  'account',
#  'purposes,',
#  'this',
#  'ao',
#  'will',
#  'be',
#  'refer',
#  'to',
#  'as',
#  'fas',
#  '-',
#  'xxx',
#  '-',
#  '001',
#  'work',
#  'activ',
#  'the',
#  'work',
#  'activ',
#  'in',
#  'which',
#  'compani',
#  'expect',
#  'consult',
#  'to',
#  'be',
#  'engag',
#  'is',
#  'categor',
#  'as',
#  'follows:',
#  '<natur',
#  'of',
#  'servic',
#  '>',
#  'compris',
#  'a',
#  'team',
#  'of',
#  ':',
#  '1.',
#  '<team',
#  'size>',
#  'work',
#  'hour',
#  'each',
#  'month',
#  'will',
#  'consi',
#  't',
#  'of',
#  'the',
#  'actual',
#  'number',
#  'of',
#  'work',
#  'day',
#  'in',
#  'that',
#  'month',
#  'and',
#  'each',
#  'week',
#  'to',
#  'consist',
#  'of',
#  'a',
#  'maximum',
#  'of',
#  '5',
#  'work',
#  'day',
#  '(monday',
#  'through',
#  'friday)',
#  'with',
#  'a',
#  'maximum',
#  'of',
#  '45',
#  'hours.',
#  'compani',
#  'shall',
#  'grant',
#  'consult',
#  'f',
#  'as',
#  'compani',
#  'declar',
#  'holiday',
#  'and',
#  '21',
#  'day',
#  'as',
#  'person',
#  'vacat',
#  'dure',
#  'each',
#  'calendar',
#  'year',
#  'for',
#  'which',
#  'there',
#  'would',
#  'be',
#  'no',
#  'deduct',
#  'in',
#  'payment',
#  '/',
#  'invoice.',
#  'all',
#  'overtim',
#  'will',
#  'be',
#  'separ',
#  'identifi',
#  'and',
#  'charg',
#  'd',
#  'on',
#  'pro',
#  '-',
#  'rata',
#  'basis.',
#  'profession',
#  'servic',
#  'bill',
#  'rate',
#  'consult',
#  'will',
#  'accru',
#  'earn',
#  'at',
#  't',
#  'he',
#  'rate',
#  'of',
#  '<rate',
#  'in',
#  'figure>',
#  '(us',
#  'dollar/rupe',
#  '<in',
#  'words>',
#  'only)',
#  'requir',
#  'training,',
#  'work',
#  'equip',
#  'and',
#  'softwar',
#  'the',
#  'work',
#  'defin',
#  'in',
#  'this',
#  'ao',
#  'will',
#  'requir',
#  'certain',
#  'training,',
#  'equip',
#  'and',
#  'software.',
#  'it',
#  'is',
#  'the',
#  'respons',
#  'of',
#  'compani',
#  'to',
#  'provid',
#  'all',
#  'train',
#  ',',
#  'hardwar',
#  'and',
#  'softwar',
#  'for',
#  'use',
#  'by',
#  'consult',
#  'in',
#  'the',
#  'complet',
#  'of',
#  'this',
#  'assign',
#  'order.',
#  'travel',
#  'consult',
#  'may',
#  'be',
#  'expect',
#  'to',
#  'travel',
#  'to',
#  'complet',
#  'the',
#  'work',
#  'activ',
#  'list',
#  'in',
#  'this',
#  'assign',
#  'order.',
#  'compani',
#  'agre',
#  'to',
#  'pay',
#  'for',
#  'all',
#  'expens',
#  'met',
#  'by',
#  'consult',
#  'for',
#  'such',
#  'travel',
#  'includ',
#  'but',
#  'not',
#  'limit',
#  'to',
#  'airfare,',
#  'lodging,',
#  'meal',
#  'etc.',
#  'agre',
#  'and',
#  'accept',
#  'by:',
#  'forgeahead',
#  'solut',
#  ',',
#  'inc.',
#  '<',
#  'compani',
#  'name>',
#  '<name>',
#  '<name>',
#  '<title>',
#  '<title>']

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatized_list = [lemmatizer.lemmatize(token) for token in list1]
print(' '.join(lemmatized_list))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Rohaan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# fa - xxx - 001 confidential page 1 of 1 <date> assignment order assignment order ao under the term and condition of the professional service agreement between < company name> and forgeahead solution , inc. <da te> . under this ao , consultant will provide service a defined below in work activities. the expected period of performance will be from <start date> through <end date> . this assignment order form and shall always be deemed to have formed an integral pa rt of the agreement. in the event of any conflict or inconsistency between the provision of the agreement and this assignment order, the provision of this assignment order will prevail. project name <project name if any> ao # for billing and accounting purposes, this ao will be referred to a fa - xxx - 001 work activity the work activity in which company expects consultant to be engaged is categorized a follows: <nature of service > comprising a team of : 1. <team size> work hour each month will consis t of the actual number of working day in that month and each week to consist of a maximum of 5 working day (monday through friday) with a maximum of 45 hours. company shall grant consultant f a company declared holiday and 21 day a personal vacation during each calendar year for which there would be no deduction in payment / invoice. all overtime will be separately identified and charge d on pro - rata basis. professional service billing rate consultant will accrue earnings at t he rate of <rate in figure> (us dollar/rupees <in words> only) required training, work equipment and software the work defined in this ao will require certain training, equipment and software. it is the responsibility of company to provide all training , hardware and software for use by consultant in the completion of this assignment order. travel consultant may be expected to travel to complete the work activity listed in this assignment order. company agrees to pay for all expense met by consultant for such travel including but not limited to airfare, lodging, meal etc. agreed and accepted by: forgeahead solution , inc. < company name> <name> <name> <title> <title>

# %%
lemmatized_list
# Out:
# ['fa',
#  '-',
#  'xxx',
#  '-',
#  '001',
#  'confidential',
#  'page',
#  '1',
#  'of',
#  '1',
#  '<date>',
#  'assignment',
#  'order',
#  'assignment',
#  'order',
#  'ao',
#  'under',
#  'the',
#  'term',
#  'and',
#  'condition',
#  'of',
#  'the',
#  'professional',
#  'service',
#  'agreement',
#  'between',
#  '<',
#  'company',
#  'name>',
#  'and',
#  'forgeahead',
#  'solution',
#  ',',
#  'inc.',
#  '<da',
#  'te>',
#  '.',
#  'under',
#  'this',
#  'ao',
#  ',',
#  'consultant',
#  'will',
#  'provide',
#  'service',
#  'a',
#  'defined',
#  'below',
#  'in',
#  'work',
#  'activities.',
#  'the',
#  'expected',
#  'period',
#  'of',
#  'performance',
#  'will',
#  'be',
#  'from',
#  '<start',
#  'date>',
#  'through',
#  '<end',
#  'date>',
#  '.',
#  'this',
#  'assignment',
#  'order',
#  'form',
#  'and',
#  'shall',
#  'always',
#  'be',
#  'deemed',
#  'to',
#  'have',
#  'formed',
#  'an',
#  'integral',
#  'pa',
#  'rt',
#  'of',
#  'the',
#  'agreement.',
#  'in',
#  'the',
#  'event',
#  'of',
#  'any',
#  'conflict',
#  'or',
#  'inconsistency',
#  'between',
#  'the',
#  'provision',
#  'of',
#  'the',
#  'agreement',
#  'and',
#  'this',
#  'assignment',
#  'order,',
#  'the',
#  'provision',
#  'of',
#  'this',
#  'assignment',
#  'order',
#  'will',
#  'prevail.',
#  'project',
#  'name',
#  '<project',
#  'name',
#  'if',
#  'any>',
#  'ao',
#  '#',
#  'for',
#  'billing',
#  'and',
#  'accounting',
#  'purposes,',
#  'this',
#  'ao',
#  'will',
#  'be',
#  'referred',
#  'to',
#  'a',
#  'fa',
#  '-',
#  'xxx',
#  '-',
#  '001',
#  'work',
#  'activity',
#  'the',
#  'work',
#  'activity',
#  'in',
#  'which',
#  'company',
#  'expects',
#  'consultant',
#  'to',
#  'be',
#  'engaged',
#  'is',
#  'categorized',
#  'a',
#  'follows:',
#  '<nature',
#  'of',
#  'service',
#  '>',
#  'comprising',
#  'a',
#  'team',
#  'of',
#  ':',
#  '1.',
#  '<team',
#  'size>',
#  'work',
#  'hour',
#  'each',
#  'month',
#  'will',
#  'consis',
#  't',
#  'of',
#  'the',
#  'actual',
#  'number',
#  'of',
#  'working',
#  'day',
#  'in',
#  'that',
#  'month',
#  'and',
#  'each',
#  'week',
#  'to',
#  'consist',
#  'of',
#  'a',
#  'maximum',
#  'of',
#  '5',
#  'working',
#  'day',
#  '(monday',
#  'through',
#  'friday)',
#  'with',
#  'a',
#  'maximum',
#  'of',
#  '45',
#  'hours.',
#  'company',
#  'shall',
#  'grant',
#  'consultant',
#  'f',
#  'a',
#  'company',
#  'declared',
#  'holiday',
#  'and',
#  '21',
#  'day',
#  'a',
#  'personal',
#  'vacation',
#  'during',
#  'each',
#  'calendar',
#  'year',
#  'for',
#  'which',
#  'there',
#  'would',
#  'be',
#  'no',
#  'deduction',
#  'in',
#  'payment',
#  '/',
#  'invoice.',
#  'all',
#  'overtime',
#  'will',
#  'be',
#  'separately',
#  'identified',
#  'and',
#  'charge',
#  'd',
#  'on',
#  'pro',
#  '-',
#  'rata',
#  'basis.',
#  'professional',
#  'service',
#  'billing',
#  'rate',
#  'consultant',
#  'will',
#  'accrue',
#  'earnings',
#  'at',
#  't',
#  'he',
#  'rate',
#  'of',
#  '<rate',
#  'in',
#  'figure>',
#  '(us',
#  'dollar/rupees',
#  '<in',
#  'words>',
#  'only)',
#  'required',
#  'training,',
#  'work',
#  'equipment',
#  'and',
#  'software',
#  'the',
#  'work',
#  'defined',
#  'in',
#  'this',
#  'ao',
#  'will',
#  'require',
#  'certain',
#  'training,',
#  'equipment',
#  'and',
#  'software.',
#  'it',
#  'is',
#  'the',
#  'responsibility',
#  'of',
#  'company',
#  'to',
#  'provide',
#  'all',
#  'training',
#  ',',
#  'hardware',
#  'and',
#  'software',
#  'for',
#  'use',
#  'by',
#  'consultant',
#  'in',
#  'the',
#  'completion',
#  'of',
#  'this',
#  'assignment',
#  'order.',
#  'travel',
#  'consultant',
#  'may',
#  'be',
#  'expected',
#  'to',
#  'travel',
#  'to',
#  'complete',
#  'the',
#  'work',
#  'activity',
#  'listed',
#  'in',
#  'this',
#  'assignment',
#  'order.',
#  'company',
#  'agrees',
#  'to',
#  'pay',
#  'for',
#  'all',
#  'expense',
#  'met',
#  'by',
#  'consultant',
#  'for',
#  'such',
#  'travel',
#  'including',
#  'but',
#  'not',
#  'limited',
#  'to',
#  'airfare,',
#  'lodging,',
#  'meal',
#  'etc.',
#  'agreed',
#  'and',
#  'accepted',
#  'by:',
#  'forgeahead',
#  'solution',
#  ',',
#  'inc.',
#  '<',
#  'company',
#  'name>',
#  '<name>',
#  '<name>',
#  '<title>',
#  '<title>']

# %% [markdown]
# ## STEP 5: Remove stopwords from corpus

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
", ".join(stop)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Rohaan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# "what, against, no, wasn't, mustn, shan, d, hers, my, being, did, weren, myself, was, am, wouldn't, doing, ve, ours, shouldn, s, but, ourselves, into, needn, me, isn't, mightn, wouldn, just, herself, doesn, her, had, an, now, ain, been, all, those, will, o, only, didn, for, them, while, hadn't, you'd, is, on, won't, that'll, at, by, after, weren't, m, haven't, down, once, during, can, until, you, in, more, this, be, or, than, t, some, couldn't, very, they, you've, then, own, were, you'll, are, to, haven, such, the, your, between, re, which, under, theirs, ll, when, shan't, from, she's, both, not, other, won, their, as, because, we, how, has, isn, nor, where, any, themselves, who, ma, aren, it, our, y, same, over, himself, mightn't, do, a, couldn, hasn't, don, it's, does, itself, whom, and, his, before, that, wasn, too, have, should've, so, these, up, with, aren't, out, she, again, why, few, mustn't, shouldn't, yourselves, most, he, yourself, further, should, its, yours, of, i, if, didn't, there, you're, needn't, off, hadn, above, each, about, through, doesn't, below, here, don't, hasn, having, him"

# %%
preprocessedAO = [token for token in lemmatized_list if token not in stop]
" ".join(preprocessedAO)
# Out:
# 'fa - xxx - 001 confidential page 1 1 <date> assignment order assignment order ao term condition professional service agreement < company name> forgeahead solution , inc. <da te> . ao , consultant provide service defined work activities. expected period performance <start date> <end date> . assignment order form shall always deemed formed integral pa rt agreement. event conflict inconsistency provision agreement assignment order, provision assignment order prevail. project name <project name any> ao # billing accounting purposes, ao referred fa - xxx - 001 work activity work activity company expects consultant engaged categorized follows: <nature service > comprising team : 1. <team size> work hour month consis actual number working day month week consist maximum 5 working day (monday friday) maximum 45 hours. company shall grant consultant f company declared holiday 21 day personal vacation calendar year would deduction payment / invoice. overtime separately identified charge pro - rata basis. professional service billing rate consultant accrue earnings rate <rate figure> (us dollar/rupees <in words> only) required training, work equipment software work defined ao require certain training, equipment software. responsibility company provide training , hardware software use consultant completion assignment order. travel consultant may expected travel complete work activity listed assignment order. company agrees pay expense met consultant travel including limited airfare, lodging, meal etc. agreed accepted by: forgeahead solution , inc. < company name> <name> <name> <title> <title>'

# %%
preprocessedAO
# Out:
# ['fa',
#  '-',
#  'xxx',
#  '-',
#  '001',
#  'confidential',
#  'page',
#  '1',
#  '1',
#  '<date>',
#  'assignment',
#  'order',
#  'assignment',
#  'order',
#  'ao',
#  'term',
#  'condition',
#  'professional',
#  'service',
#  'agreement',
#  '<',
#  'company',
#  'name>',
#  'forgeahead',
#  'solution',
#  ',',
#  'inc.',
#  '<da',
#  'te>',
#  '.',
#  'ao',
#  ',',
#  'consultant',
#  'provide',
#  'service',
#  'defined',
#  'work',
#  'activities.',
#  'expected',
#  'period',
#  'performance',
#  '<start',
#  'date>',
#  '<end',
#  'date>',
#  '.',
#  'assignment',
#  'order',
#  'form',
#  'shall',
#  'always',
#  'deemed',
#  'formed',
#  'integral',
#  'pa',
#  'rt',
#  'agreement.',
#  'event',
#  'conflict',
#  'inconsistency',
#  'provision',
#  'agreement',
#  'assignment',
#  'order,',
#  'provision',
#  'assignment',
#  'order',
#  'prevail.',
#  'project',
#  'name',
#  '<project',
#  'name',
#  'any>',
#  'ao',
#  '#',
#  'billing',
#  'accounting',
#  'purposes,',
#  'ao',
#  'referred',
#  'fa',
#  '-',
#  'xxx',
#  '-',
#  '001',
#  'work',
#  'activity',
#  'work',
#  'activity',
#  'company',
#  'expects',
#  'consultant',
#  'engaged',
#  'categorized',
#  'follows:',
#  '<nature',
#  'service',
#  '>',
#  'comprising',
#  'team',
#  ':',
#  '1.',
#  '<team',
#  'size>',
#  'work',
#  'hour',
#  'month',
#  'consis',
#  'actual',
#  'number',
#  'working',
#  'day',
#  'month',
#  'week',
#  'consist',
#  'maximum',
#  '5',
#  'working',
#  'day',
#  '(monday',
#  'friday)',
#  'maximum',
#  '45',
#  'hours.',
#  'company',
#  'shall',
#  'grant',
#  'consultant',
#  'f',
#  'company',
#  'declared',
#  'holiday',
#  '21',
#  'day',
#  'personal',
#  'vacation',
#  'calendar',
#  'year',
#  'would',
#  'deduction',
#  'payment',
#  '/',
#  'invoice.',
#  'overtime',
#  'separately',
#  'identified',
#  'charge',
#  'pro',
#  '-',
#  'rata',
#  'basis.',
#  'professional',
#  'service',
#  'billing',
#  'rate',
#  'consultant',
#  'accrue',
#  'earnings',
#  'rate',
#  '<rate',
#  'figure>',
#  '(us',
#  'dollar/rupees',
#  '<in',
#  'words>',
#  'only)',
#  'required',
#  'training,',
#  'work',
#  'equipment',
#  'software',
#  'work',
#  'defined',
#  'ao',
#  'require',
#  'certain',
#  'training,',
#  'equipment',
#  'software.',
#  'responsibility',
#  'company',
#  'provide',
#  'training',
#  ',',
#  'hardware',
#  'software',
#  'use',
#  'consultant',
#  'completion',
#  'assignment',
#  'order.',
#  'travel',
#  'consultant',
#  'may',
#  'expected',
#  'travel',
#  'complete',
#  'work',
#  'activity',
#  'listed',
#  'assignment',
#  'order.',
#  'company',
#  'agrees',
#  'pay',
#  'expense',
#  'met',
#  'consultant',
#  'travel',
#  'including',
#  'limited',
#  'airfare,',
#  'lodging,',
#  'meal',
#  'etc.',
#  'agreed',
#  'accepted',
#  'by:',
#  'forgeahead',
#  'solution',
#  ',',
#  'inc.',
#  '<',
#  'company',
#  'name>',
#  '<name>',
#  '<name>',
#  '<title>',
#  '<title>']

# %% [markdown]
# ## STEP 6: Do the similar process for other contract types in order to build your Database

# %% [markdown]
# Below contract being extracted is a Non Disclosure Agreement Contract

# %%
file = open('Contract-NDA.pdf', 'rb')
pdf_reader = pdf.PdfFileReader(file)
pdf_reader.getNumPages()
page1 = pdf_reader.getPage(0)
Page1 = str(page1.extractText())
Page1 = Page1.lower()
list1 = Page1.split()
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatized_list = [lemmatizer.lemmatize(token) for token in list1]
preprocessedNDA = [token for token in lemmatized_list if token not in stop]
" ".join(preprocessedNDA)
# Out:
# 'confidentiality agreement effective date: agreement made forgeahead solution pvt . ltd . , suite 218, b1 - cerebrum park, kalyani nagar, pune 411014 (india) ffiliates forgeahead ( whereas , forgeahead company mutually desire engage discussion may lead business relationship involving companies; whereas , party course dealing may furnish "confidential information" defined paragraph 1 wish convey interest copyright therein other, make confidential information public common knowledge; disclosed third party, permit use reof except engage discussion now, therefore , consideration business discussions, disclosure confidential information future business relationship parties, hereby agreed follows: 1. confidential inform ation. purpose agreement, term "confidential information" shall mean following: information, business plan, concept, idea, know - how, process, technique, program, design, formula, algorithm work - - process, engineering, manu facturing, marketing, technical, financial data, sale information, information regarding suppliers, customers, employees, investors, pricing business operations, information materials, whether written, graphic, ther form whether disclosed orally, electronically, whether tangible intangible whatever form medium provided, otherwise learned disclosed course discussions, studies, work undertaken parties. without limiting generality foregoing, confidential information shall include information material disclosed orally form, includin g, limited to, configuration techniques, data classification techniques, user interface, application programming interfaces, data modeling management techniques, data structures, information product derived testing use thereof. confidential information shall include information included paragraph 6. 2. joint undertaking . both, forgeahead company agree period five (5) year date receipt time disclose, give, transmit manner form purpose, confidential information received party person, party, firm corporation entity use confidential information benefit benefit anyone else, purpose engage discussion regarding possible business relationship involving parties. without limitatio n generality foregoing, neither party may use, refer otherwise benefit confidential information party development, planning, marketing business activities. both, forgeahead company shall take reasonable measure confidential information, including limited step taken respect party shall disassemble, decompile otherwise reverse engineer software product party and, extent activity may permitted, result thereof shall deemed confidential information subject requirement agreement. 3. return confidential information. upon request party, upon termination discussion regarding business relationship parties, party shall promptly deliver documents, notes, physical embodiment reflecting confidential information (including copy thereof) possession control. request either party, respon sible officer party shall verify, provide party written certification of, completeness delivery materials. 4. nonconveyance. nothing agreement shall construed conveying either party righ t, title interest copyright confidential information party; convey license use, sell, exploit, copy develop confidential information. 5. nondisclosure discussions. party agrees tha t, addition confidentiality obligation hereunder, disclose third party discussion party respect establishing business relationship. 6. excluded information. partie agree mutual covenant disclose use confidential information party shall apply information extent information: a. is, time becomes part public domain act omission f receiving party; b. independently discovered developed receiving party using individual contact confidential information party; c. rightfully obtained third party without obligation conf identiality; d. already known recipient without obligation confidentiality prior obtaining confidential information disclosing party. 7. court ordered disclosure. neithe ...

# %%
preprocessedNDA
# Out:
# ['confidentiality',
#  'agreement',
#  'effective',
#  'date:',
#  'agreement',
#  'made',
#  'forgeahead',
#  'solution',
#  'pvt',
#  '.',
#  'ltd',
#  '.',
#  ',',
#  'suite',
#  '218,',
#  'b1',
#  '-',
#  'cerebrum',
#  'park,',
#  'kalyani',
#  'nagar,',
#  'pune',
#  '411014',
#  '(india)',
#  'ffiliates',
#  'forgeahead',
#  '(',
#  'whereas',
#  ',',
#  'forgeahead',
#  'company',
#  'mutually',
#  'desire',
#  'engage',
#  'discussion',
#  'may',
#  'lead',
#  'business',
#  'relationship',
#  'involving',
#  'companies;',
#  'whereas',
#  ',',
#  'party',
#  'course',
#  'dealing',
#  'may',
#  'furnish',
#  '"confidential',
#  'information"',
#  'defined',
#  'paragraph',
#  '1',
#  'wish',
#  'convey',
#  'interest',
#  'copyright',
#  'therein',
#  'other,',
#  'make',
#  'confidential',
#  'information',
#  'public',
#  'common',
#  'knowledge;',
#  'disclosed',
#  'third',
#  'party,',
#  'permit',
#  'use',
#  'reof',
#  'except',
#  'engage',
#  'discussion',
#  'now,',
#  'therefore',
#  ',',
#  'consideration',
#  'business',
#  'discussions,',
#  'disclosure',
#  'confidential',
#  'information',
#  'future',
#  'business',
#  'relationship',
#  'parties,',
#  'hereby',
#  'agreed',
#  'follows:',
#  '1.',
#  'confidential',
#  'inform',
#  'ation.',
#  'purpose',
#  'agreement,',
#  'term',
#  '"confidential',
#  'information"',
#  'shall',
#  'mean',
#  'following:',
#  'information,',
#  'business',
#  'plan,',
#  'concept,',
#  'idea,',
#  'know',
#  '-',
#  'how,',
#  'process,',
#  'technique,',
#  'program,',
#  'design,',
#  'formula,',
#  'algorithm',
#  'work',
#  '-',
#  '-',
#  'process,',
#  'engineering,',
#  'manu',
#  'facturing,',
#  'marketing,',
#  'technical,',
#  'financial',
#  'data,',
#  'sale',
#  'information,',
#  'information',
#  'regarding',
#  'suppliers,',
#  'customers,',
#  'employees,',
#  'investors,',
#  'pricing',
#  'business',
#  'operations,',
#  'information',
#  'materials,',
#  'whether',
#  'written,',
#  'graphic,',
#  'ther',
#  'form',
#  'whether',
#  'disclosed',
#  'orally,',
#  'electronically,',
#  'whether',
#  'tangible',
#  'intangible',
#  'whatever',
#  'form',
#  'medium',
#  'provided,',
#  'otherwise',
#  'learned',
#  'disclosed',
#  'course',
#  'discussions,',
#  'studies,',
#  'work',
#  'undertaken',
#  'parties.',
#  'without',
#  'limiting',
#  'generality',
#  'foregoing,',
#  'confidential',
#  'information',
#  'shall',
#  'include',
#  'information',
#  'material',
#  'disclosed',
#  'orally',
#  'form,',
#  'includin',
#  'g,',
#  'limited',
#  'to,',
#  'configuration',
#  'techniques,',
#  'data',
#  'classification',
#  'techniques,',
#  'user',
#  'interface,',
#  'application',
#  'programming',
#  'interfaces,',
#  'data',
#  'modeling',
#  'management',
#  'techniques,',
#  'data',
#  'structures,',
#  'information',
#  'product',
#  'derived',
#  'testing',
#  'use',
#  'thereof.',
#  'confidential',
#  'information',
#  'shall',
#  'include',
#  'information',
#  'included',
#  'paragraph',
#  '6.',
#  '2.',
#  'joint',
#  'undertaking',
#  '.',
#  'both,',
#  'forgeahead',
#  'company',
#  'agree',
#  'period',
#  'five',
#  '(5)',
#  'year',
#  'date',
#  'receipt',
#  'time',
#  'disclose,',
#  'give,',
#  'transmit',
#  'manner',
#  'form',
#  'purpose,',
#  'confidential',
#  'information',
#  'received',
#  'party',
#  'person,',
#  'party,',
#  'firm',
#  'corporation',
#  'entity',
#  'use',
#  'confidential',
#  'information',
#  'benefit',
#  'benefit',
#  'anyone',
#  'else,',
#  'purpose',
#  'engage',
#  'discussion',
#  'regarding',
#  'possible',
#  'business',
#  'relationship',
#  'involving',
#  'parties.',
#  'without',
#  'limitatio',
#  'n',
#  'generality',
#  'foregoing,',
#  'neither',
#  'party',
#  'may',
#  'use,',
#  'refer',
#  'otherwise',
#  'benefit',
#  'confidential',
#  'information',
#  'party',
#  'development,',
#  'planning,',
#  'marketing',
#  'business',
#  'activities.',
#  'both,',
#  'forgeahead',
#  'company',
#  'shall',
#  'take',
#  'reasonable',
#  'measure',
#  'confidential',
#  'information,',
#  'including',
#  'limited',
#  'step',
#  'taken',
#  'respect',
#  'party',
#  'shall',
#  'disassemble,',
#  'decompile',
#  'otherwise',
#  'reverse',
#  'engineer',
#  'software',
#  'product',
#  'party',
#  'and,',
#  'extent',
#  'activity',
#  'may',
#  'permitted,',
#  'result',
#  'thereof',
#  'shall',
#  'deemed',
#  'confidential',
#  'information',
#  'subject',
#  'requirement',
#  'agreement.',
#  '3.',
#  'return',
#  'confidential',
#  'information.',
#  'upon',
#  'request',
#  'party,',
#  'upon',
#  'termination',
#  'discussion',
#  'regarding',
#  'business',
#  'relationship',
#  'parties,',
#  'party',
#  'shall',
#  'promptly',
#  'deliver',
#  'documents,',
#  'notes,',
#  'physical',
#  'embodiment',
#  'reflecting',
#  'confidential',
#  'information',
#  '(including',
#  'copy',
#  'thereof)',
#  'possession',
#  'control.',
#  'request',
#  'either',
#  'party,',
#  'respon',
#  'sible',
#  'officer',
#  'party',
#  'shall',
#  'verify,',
#  'provide',
#  'party',
#  'written',
#  'certification',
#  'of,',
#  'completeness',
#  'delivery',
#  'materials.',
#  '4.',
#  'nonconveyance.',
#  'nothing',
#  'agreement',
#  'shall',
#  'construed',
#  'conveying',
#  'either',
#  'party',
#  'righ',
#  't,',
#  'title',
#  'interest',
#  'copyright',
#  'confidential',
#  'information',
#  'party;',
#  'convey',
#  'license',
#  'use,',
#  'sell,',
#  'exploit,',
#  'copy',
#  'develop',
#  'confidential',
#  'information.',
#  '5.',
#  'nondisclosure',
#  'discussions.',
#  'party',
#  'agrees',
#  'tha',
#  't,',
#  'addition',
#  'confidentiality',
#  'obligation',
#  'hereunder,',
#  'disclose',
#  'third',
#  'party',
#  'discussion',
#  'party',
#  'respect',
#  'establishing',
#  'business',
#  'relationship.',
#  '6.',
#  'excluded',
#  'information.',
#  'partie',
#  'agree',
#  'mutual',
#  'covenant',
#  'disclose',
#  'use',
#  'confidential',
#  'information',
#  'party',
#  'shall',
#  'apply',
#  'information',
#  'extent',
#  'information:',
#  'a.',
#  'is,',
#  'time',
#  'becomes',
#  'part',
#  'public',
#  'domain',
#  'act',
#  'omission',
#  'f',
#  'receiving',
#  'party;',
#  'b.',
#  'independently',
#  'discovered',
#  'developed',
#  'receiving',
#  'party',
#  'using',
#  'individual',
#  'contact',
#  'confidential',
#  'information',
#  'party;',
#  'c.',
#  'rightfully',
#  'obtained',
#  'third',
#  'party',
#  'without',
#  'obligation',
#  'conf',
#  'identiality;',
#  'd.',
#  'already',
#  'known',
#  'recipient',
#  'without',
#  'obligation',
#  'confidentiality',
#  'prior',
#  'obtaining',
#  'confidential',
#  'information',
#  'disclosing',
#  'party.',
#  '7.',
#  'court',
#  'ordered',
#  'disclosure.',
#  'neither',
#  'party',
#  'shall',
#  'liable',
#  'disclosure',
#  'confidential',
#  'informati',
#  'made',
#  'response',
#  'valid',
#  'order',
#  'court',
#  'authorized',
#  'agency',
#  'government;',
#  'provided,',
#  'notice',
#  'given',
#  'promptly',
#  'party',
#  'whose',
#  'confidential',
#  'information',
#  'disclosed',
#  'party',
#  'may',
#  'seek',
#  'protective',
#  'order',
#  'and/or',
#  'engage',
#  'effort',
#  'minimize',
#  'required',
#  'disclosure.',
#  'party',
#  'shall',
#  'cooperate',
#  'seeking',
#  'protective',
#  'order',
#  'engaging',
#  'efforts.',
#  '8.',
#  'commitment.',
#  'agreement',
#  'doe',
#  'way',
#  'bind',
#  'party',
#  'enter',
#  'business',
#  'relationship',
#  'nature',
#  'other.',
#  'nothing',
#  'herein',
#  'verbal',
#  'representation',
#  'made',
#  'either',
#  'party',
#  'shall',
#  'construed',
#  'binding',
#  'commitment',
#  'establish',
#  'bus',
#  'iness',
#  'relationship.',
#  'neither',
#  'party',
#  'shall',
#  'liability',
#  'other,',
#  'except',
#  'breach',
#  'agreement,',
#  'party',
#  'establish',
#  'business',
#  'relationship',
#  'expressed',
#  'writing',
#  'expressly',
#  'stated',
#  'legally',
#  'binding.',
#  '9.',
#  'injunctive',
#  'r',
#  'elief.',
#  'party',
#  'acknowledge',
#  'monetary',
#  'damage',
#  'alone',
#  'may',
#  'sufficient',
#  'remedy',
#  'unauthorized',
#  'disclosure',
#  'confidential',
#  'information',
#  'either',
#  'party',
#  'shall',
#  'entitled,',
#  'without',
#  'waiving',
#  'right',
#  'remedies,',
#  'seek',
#  'injunct',
#  'ive',
#  'equitable',
#  'relief',
#  'may',
#  'deemed',
#  'proper',
#  'court',
#  'competent',
#  'jurisdiction.',
#  '10.',
#  "attorney's",
#  'fees.',
#  'event',
#  'action,',
#  'including',
#  'arbitration,',
#  'brought',
#  'enforce',
#  'provision',
#  'agreement,',
#  'declare',
#  'breach',
#  'agreement,',
#  'pre',
#  'vailing',
#  'party',
#  'shall',
#  'entitled',
#  'recover,',
#  'addition',
#  'amount',
#  'awarded,',
#  'reasonable',
#  'legal',
#  'related',
#  'cost',
#  '11.',
#  'nonassignment.',
#  'neither',
#  'party',
#  'may',
#  'assign',
#  'transfer',
#  'agreement',
#  'right',
#  'hereunder',
#  'third',
#  'party',
#  'without',
#  'prior',
#  'written',
#  'consent',
#  'party.',
#  '1',
#  '2',
#  '.',
#  'entire',
#  'agreement.',
#  'agreement',
#  'constitutes',
#  'entire',
#  'agreement',
#  'b',
#  'party',
#  'regarding',
#  'subject',
#  'matter',
#  'addressed',
#  'thereof',
#  'supercedes',
#  'proposal',
#  'prior',
#  'discussion',
#  'writing',
#  'party',
#  'respect',
#  'thereto.',
#  'party',
#  'agree',
#  'agreement',
#  'may',
#  'altered,',
#  'amended',
#  'modified',
#  'except',
#  'writing',
#  'signed',
#  'authorized',
#  'representative',
#  'parties.',
#  '1',
#  '3',
#  '.',
#  'non',
#  'solicitation:',
#  'party',
#  'recognize',
#  'employee',
#  'valuable',
#  'asset',
#  'employing',
#  'company.',
#  'accordingly,',
#  'party',
#  'hereby',
#  'agree,',
#  'make',
#  'offer',
#  'employment',
#  'to,',
#  'enter',
#  'consulting',
#  'relationship',
#  '(nor',
#  'directly',
#  'indirectly',
#  'assist',
#  'person',
#  'entity',
#  'employ',
#  'enter',
#  'consulting',
#  'relation',
#  'with),',
#  'person',
#  'employed',
#  'party',
#  'term',
#  'agreement',
#  'period',
#  'twelve',
#  'calendar',
#  '1',
#  '4',
#  '.',
#  'governing',
#  'law',
#  '.',
#  'agreement',
#  'shall',
#  'governed',
#  'construed',
#  'accordance',
#  'law',
#  'india',
#  'subject',
#  'pune',
#  'jurisdiction',
#  '.',
#  'witness',
#  'whereof',
#  ',',
#  'agreement',
#  'ha',
#  'duly',
#  'executed',
#  'party',
#  'hereto',
#  'latest',
#  'date',
#  'set',
#  'forth',
#  'below:',
#  'forgeahead',
#  'solution',
#  'pvt',
#  '.',
#  'ltd',
#  '.',
#  'company:',
#  'sign.',
#  'sign.',
#  'authorized',
#  'signature',
#  'title',
#  'authorized',
#  'signature',
#  'title',
#  'name',
#  'printed',
#  'typed',
#  'date',
#  'name',
#  'printed',
#  'typed',
#  'date']

# %% [markdown]
# Below contract being extracted is a Work Schedule Contract

# %%
file = open('Contract-WS.pdf', 'rb')
pdf_reader = pdf.PdfFileReader(file)
pdf_reader.getNumPages()
page1 = pdf_reader.getPage(0)
Page1 = str(page1.extractText())
Page1 = Page1.lower()
list1 = Page1.split()
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatized_list = [lemmatizer.lemmatize(token) for token in list1]
preprocessedWS = [token for token in lemmatized_list if token not in stop]
" ".join(preprocessedWS)
# Out:
# 'fa - xxx - 001 confidential page 1 1 <date> work schedule letter serf work schedule sow term condition master service agreement <client name> client forgea head solution , inc. provider <date>. sow , provider provide service defined work activities. expected period performance <start date> <end date> . work schedule form shall always deemed formed integral part agreem ent. event conflict inconsistency provision agreement work schedule , provision work schedule prevail. project name <project name any> sow # billing accounting purposes, sow w ill referred fa - xxx - 001 work activity work activity client expects provider engaged categorized follows: <nature service > comprising team : 1. <team detail > project fee provider accrue earnings rat e <rate figure> (us dollar <in words> only) invoicing payment project fee & expense provider may submit invoice project fee end calendar month. provider may submit invoice reimbursement expense immediately n meeting expenses. payment made per term defined agreement. required training, work equipment software work defined sow require certain training, equipment software. responsibility client pr ovide training responsibility provider provide regular hardware software use provider completion work schedule . client require additional hardware, software etc. client agrees provide ar cost mutually decided client provider. travel provider expected travel complete work activity listed work schedule . client require provider client agrees pay expense met provider travel including lim ited airfare, lodging & per diem cover basic sustenance . agreed accepted by: forgea head solution , inc. < name> <name> <name> <title > <title>'

# %%
preprocessedWS
# Out:
# ['fa',
#  '-',
#  'xxx',
#  '-',
#  '001',
#  'confidential',
#  'page',
#  '1',
#  '1',
#  '<date>',
#  'work',
#  'schedule',
#  'letter',
#  'serf',
#  'work',
#  'schedule',
#  'sow',
#  'term',
#  'condition',
#  'master',
#  'service',
#  'agreement',
#  '<client',
#  'name>',
#  'client',
#  'forgea',
#  'head',
#  'solution',
#  ',',
#  'inc.',
#  'provider',
#  '<date>.',
#  'sow',
#  ',',
#  'provider',
#  'provide',
#  'service',
#  'defined',
#  'work',
#  'activities.',
#  'expected',
#  'period',
#  'performance',
#  '<start',
#  'date>',
#  '<end',
#  'date>',
#  '.',
#  'work',
#  'schedule',
#  'form',
#  'shall',
#  'always',
#  'deemed',
#  'formed',
#  'integral',
#  'part',
#  'agreem',
#  'ent.',
#  'event',
#  'conflict',
#  'inconsistency',
#  'provision',
#  'agreement',
#  'work',
#  'schedule',
#  ',',
#  'provision',
#  'work',
#  'schedule',
#  'prevail.',
#  'project',
#  'name',
#  '<project',
#  'name',
#  'any>',
#  'sow',
#  '#',
#  'billing',
#  'accounting',
#  'purposes,',
#  'sow',
#  'w',
#  'ill',
#  'referred',
#  'fa',
#  '-',
#  'xxx',
#  '-',
#  '001',
#  'work',
#  'activity',
#  'work',
#  'activity',
#  'client',
#  'expects',
#  'provider',
#  'engaged',
#  'categorized',
#  'follows:',
#  '<nature',
#  'service',
#  '>',
#  'comprising',
#  'team',
#  ':',
#  '1.',
#  '<team',
#  'detail',
#  '>',
#  'project',
#  'fee',
#  'provider',
#  'accrue',
#  'earnings',
#  'rat',
#  'e',
#  '<rate',
#  'figure>',
#  '(us',
#  'dollar',
#  '<in',
#  'words>',
#  'only)',
#  'invoicing',
#  'payment',
#  'project',
#  'fee',
#  '&',
#  'expense',
#  'provider',
#  'may',
#  'submit',
#  'invoice',
#  'project',
#  'fee',
#  'end',
#  'calendar',
#  'month.',
#  'provider',
#  'may',
#  'submit',
#  'invoice',
#  'reimbursement',
#  'expense',
#  'immediately',
#  'n',
#  'meeting',
#  'expenses.',
#  'payment',
#  'made',
#  'per',
#  'term',
#  'defined',
#  'agreement.',
#  'required',
#  'training,',
#  'work',
#  'equipment',
#  'software',
#  'work',
#  'defined',
#  'sow',
#  'require',
#  'certain',
#  'training,',
#  'equipment',
#  'software.',
#  'responsibility',
#  'client',
#  'pr',
#  'ovide',
#  'training',
#  'responsibility',
#  'provider',
#  'provide',
#  'regular',
#  'hardware',
#  'software',
#  'use',
#  'provider',
#  'completion',
#  'work',
#  'schedule',
#  '.',
#  'client',
#  'require',
#  'additional',
#  'hardware,',
#  'software',
#  'etc.',
#  'client',
#  'agrees',
#  'provide',
#  'ar',
#  'cost',
#  'mutually',
#  'decided',
#  'client',
#  'provider.',
#  'travel',
#  'provider',
#  'expected',
#  'travel',
#  'complete',
#  'work',
#  'activity',
#  'listed',
#  'work',
#  'schedule',
#  '.',
#  'client',
#  'require',
#  'provider',
#  'client',
#  'agrees',
#  'pay',
#  'expense',
#  'met',
#  'provider',
#  'travel',
#  'including',
#  'lim',
#  'ited',
#  'airfare,',
#  'lodging',
#  '&',
#  'per',
#  'diem',
#  'cover',
#  'basic',
#  'sustenance',
#  '.',
#  'agreed',
#  'accepted',
#  'by:',
#  'forgea',
#  'head',
#  'solution',
#  ',',
#  'inc.',
#  '<',
#  'name>',
#  '<name>',
#  '<name>',
#  '<title',
#  '>',
#  '<title>']

# %%
file = open('Contract-MSA.pdf', 'rb')
pdf_reader = pdf.PdfFileReader(file)
count = pdf_reader.numPages
for i in range(count):
    page = pdf_reader.getPage(i)
    output = page.extractText()
output
# Out:
# 'Page \n14\n \nof \n14\n \n14.7\n \nCounterparts. \nThis Agreement may be executed in several counterparts, each of which will be \ndeemed an orig\ninal, and all of which taken together will constitute one single Agreement between the \nParties with the same effect as if all the signatures were upon the same instrument.\n \n14.8\n \nEntire Agreement\n. This Agreement and all appendices and other exhibits attached\n \nhereto \nconstitute the complete and exclusive statement of the agreement between the Parties and supersedes all \nproposals, oral or written, and all other prior or contemporaneous communications and agreement \nbetween the Parties relating to the subject matt\ner herein. \n \n14.9\n \nForce Majeure.\n  \nIn the event that either Party is prevented from performing or is unable to \nperform any of its obligations under this Agreement (other than a payment obligation) due to any act of \nfire, casualty, flood, earthquake, war, epi\ndemic, destruction of production facilities, riot, insurrection, \nmaterial unavailability, or any other cause beyond the reasonable control of the Party invoking this \nSection, and if such Party shall have used its best efforts to mitigate its effects, such \nParty shall give \nprompt written notice to the other Party, its performance shall be excused, and the time for the \nperformance shall be extended for the period of delay or inability to perform due to such occurrences.  \nNotwithstanding the foregoing, if such\n \nParty is not able to perform within thirty (30) days after the event \ngiving rise to the excuse of force majeure, the other Party may terminate this Agreement, without \nprejudice to the rights of the first Party.\n \n14.10\n \nPublicity\n. Within forty\n-\nfive (45) days\n \nafter the execution of this Agreement, subject to written \napproval of the Client which consent shall not be unreasonably withheld, both the Parties will create and \nissue a joint press release. Such press release shall, at a minimum, describe the general n\nature of the \nbusiness relationship and may include quotes from the CEO or any authorized representative of both \nParties with respect to such relationship. \n \n14.11 Use of Client Logo & Name.\n \nClient \ngrants\n \nProvider the \nlimited \n\nand / \nor logo \nto identify the Client in \nProvider \nwebsite, client lists, or marketing materials.\n \n \nIN WITNESS WHEREOF,\n \nthe Parties have caused this Agreement to be signed and delivered \nby their duly authorized officers, all as of t\nhe date first herein above written.\n \n \nForgea\nhead Solutions, Inc.\n \n \n \n \n \n<Client>\n \n \n \n \n \nBy: \n \n \n \n \n \n \n \n \nBy: \n \n \n \n \n \n \nName:\n \nAshish Shah\n \n \n \n \n \n \nName:\n \nTitle:\n \n \nPresident\n \n \n \n \n \n \nTitle:\n \n \n'
